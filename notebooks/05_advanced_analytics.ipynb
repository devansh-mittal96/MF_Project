# %% [markdown]
# # Day 6 — Advanced Analytics\n\nVaR/CVaR, rolling Sharpe, fund recommender.

# %%
from pathlib import Path
import sys

def find_root():
    cwd = Path.cwd()
    if (cwd / "data" / "raw").exists():
        return cwd
    if (cwd.parent / "data" / "raw").exists():
        return cwd.parent
    raise FileNotFoundError("Open notebook from project root or notebooks/ folder.")

ROOT = find_root()
sys.path.insert(0, str(ROOT / "scripts"))
print("Project root:", ROOT)

from recommender import recommend_funds
print(recommend_funds('High'))

# %%
import pandas as pd
pd.read_csv(ROOT / 'reports' / 'var_cvar_report.csv')

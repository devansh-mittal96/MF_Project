# %% [markdown]
# # Day 2 — Data Cleaning + SQLite\n\nClean NAV/transactions and load star schema.

# %%
from pathlib import Path
import sys

def find_root():
    cwd = Path.cwd()
    if (cwd / "data" / "raw").exists():
        return cwd
    if (cwd.parent / "data" / "raw").exists():
        return cwd.parent
    raise FileNotFoundError("Open notebook from project root or notebooks/ folder.")

ROOT = find_root()
sys.path.insert(0, str(ROOT / "scripts"))
print("Project root:", ROOT)

from etl_pipeline import run_etl
run_etl()

# %%
from pathlib import Path
print((ROOT / 'data' / 'db' / 'bluestock_mf.db').exists())
